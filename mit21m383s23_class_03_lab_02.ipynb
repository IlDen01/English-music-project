# %% [markdown]
# # 21M.383 Computational Music Theory and Analysis
# ## Lab 01: Setting up the Course Environment

# %% [markdown]
# ## Install Python and Jupyter and music21

# %% [markdown]
# We are going to do most of our course work in Python, so before going on make sure that you're on Python 3.8 or 3.9 by downloading it from https://www.python.org/  .  Later versions should work but please upgrade if you are on an earlier version.  Python 3.6 or below and 2.7 wil not run the course software.

# %% [markdown]
# Next open up the Terminal (Mac) or Command Line (PC) and install the Jupyter notebook with this command:
# ```
# pip install jupyter
# ```

# %% [markdown]
# After that, go ahead and install music21 with:
#
# ```
# pip install music21
# ```
#
# You will need music21 v.7.1 or higher to complete this class.  (If you have an earlier version, then `pip install --upgrade music21` will bring you up to date.
#
# You might as well also install Scientific Extensions to Python and the Levenshtein library for computing similarity, while you're in an installation mood.  They're not absolutely needed for this class (so don't panic if they fail) but they will speed up working in music21:
#
# ```
# pip install scipy
# pip install python-Levenshtein
# ```
#
# Now you're ready to download the next part of the assignment.

# %% [markdown]
# ## Jupyter Notebook
#
# You are looking at a Jupyter notebook. It is an interactive document, backed by a server running the jupyter app. In this class, each of you will run your own server locally from the command line:
#
# `$ jupyter notebook`
#
# From there on, you interact through the web browser.
#
# The notebook document itself is a file saved on your local computer. It has a `.ipynb` file extension. The notebook you are looking at now is called `lab_01.ipynb`
#
# If you haven't used Jupyter before, begin by going through the _User Interface Tour_ in the _Help_ Menu, and we will go through some commands:

# %% [markdown]
# ## Cells and Modes
#
# Notebooks are divided into a bunch of _cells_. Each cell can be one of two types:
# - __Markdown Cell__ used for nicely formatted text
# - __Code Cell__ used for typing and executing python code, and seeing the results
#
# Additionally, the notebook can be in one of two modes:
# - __Edit Mode__ for editing text in a cell.
# - __Command Mode__ for notebook-wide operations like adding, deleting, moving cells, or changing the cell type.
#
# In Edit Mode, the current cell has a <font color='green'>green border</font>. You enter Edit Mode by:
# - double clicking on a cell
# - hitting Enter in a cell
#
# You can _execute_ a cell. This will render a Markdown Cell or run the code of a Code Cell. You execute a cell by:
# - pressing _Shift-Enter_ (to execute and move to the next cell)
# - pressing _Control-Enter_ (to execute and stay on the current cell)
#
# Executing a cell automatically changes the mode to Command Mode. In Command Mode, the current cell has a <font color='blue'>blue border</font>. You enter Command Mode by:
# - executing a cell (_Shift-Enter_ or _Control-Enter_)
# - pressing ESC
#
# Now is an excellent time to look at keyboard shortcuts by either:
# - selecting _Help_ Menu -> _Keyboard Shortcuts_
# - pressing _h_ when in Command Mode.

# %% [markdown]
# ## Markdown
#
# [This page](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) is a good markdown cheatsheet.
#
# Markdown can also use [MathJax](http://meta.math.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) for fancy math formulas:
#
# `$\sum_{i=0}^n i^2 = \frac{(n^2+n)(2n+1)}{6}$` displays as:
#
#
# $\sum_{i=0}^n i^2 = \frac{(n^2+n)(2n+1)}{6}$
#
# But we will not use fancy math very much.

# %% [markdown]
# ## Code
#
# The next two cells are code cells. Execute the code there (with Control-Enter). Change the code and execute it again.
#
# The code cell will automatically print the last value (which you can supress with a `;` at the end).
# You can also use `print`.

# %%
4 * 7

# %%
print(7 + 5)

a = 3
b = 'hello'
c = [5, 6, 7]

print(b, [a + i for i in c])

"do not print this";

# %% [markdown]
# ## Setup / Import Music21
#
# You will usually find the next Code Cell (or something like it) at the top of a notebook. I use it to set up the python environment you'll need for the rest of the notebook.

# %%
# install music21 from
#
#    pip install music21
#
# and make sure that this line works

from music21 import *

# %% [markdown]
# If this works then try running the following line:

# %%
note.Note().show()

# %% [markdown]
# If you saw a quarter note, middle C, then you're great!
#
# You may have got an error at this point.  Don't panic!  This means that you don't have a compatible music notation program installed.  Go ahead and install MuseScore from https://musescore.org/en and then save and try again.
#
# If that does not work, you may need to go back to the command line and type `python -m music21.configure` to help music21 find your software.  If you're still having trouble, read https://www.music21.org/music21docs/usersGuide/usersGuide_01_installing.html
# and/or post to the course discussion board if you are on Mac/PC

# %% [markdown]
# If that still doesn't work, some students have reported that this helps:

# %%
# uncomment and run me.  Switch "MuseScore 3\bin\MuseScore3" to "MuseScore 4\bin\MuseScore4" as appropriate 

# from music21 import *
# us = environment.UserSettings()
# us['musescoreDirectPNGPath'] = r'C:\Program Files\MuseScore 3\bin\MuseScore3.exe'

# %% [markdown]
# ## Wrapping up
#
# Now you're in a good position to use Jupyter notebook for your assignments: **USE IT!**  :-)
#
# Now you're in a good place to use `music21` for your assignments: **DON'T USE IT!**  (WHAT???)
#
# You start out with **No music21 modules** unlocked in this class.  As we complete assignments, we will unlock certain modules (like note) and be able to do great things!  The point of this assignment is to be ready so that when we unlock modules, you're ready to go, and if there are problems, you have time to ask before there's a real issue.  But go ahead and reward yourself just one time by listening to a good middle C quarter note:

# %%
note.Note().show('midi')

# %% [markdown]
# Hopefully that played properly.  If all this worked you have a functioning lab environment.  If not, please post to the Course Discussions ASAP.
#
# :-)   MSAC  ( = Michael Scott Asato Cuthbert -- too much to write)
